# %% [markdown]
# By Sarthak Nahar
#
# INVENTORY MANAGEMENT SYSTEM

# %%
records = {1101: {"item": "Toothpaste", "price": 25, "quantity": 30, "category": "Toiletry", "expiry after months": 2},
           1102: {"item": "Carrots", "price": 50, "quantity": 24, "category": "Food", "expiry after months": 1},
           1103: {"item": "Soap", "price": 32, "quantity": 15, "category": "Toiletry", "expiry after months": 6},
           1104: {"item": "Tomatoes", "price": 40, "quantity": 12, "category": "Food", "expiry after months": 1},
           1105: {"item": "Bananas", "price": 20, "quantity": 10, "category": "Food", "expiry after months": 2},
           1106: {"item": "Socks", "price": 56, "quantity": 15, "category": "Apparel", "expiry after months": 36},
           1107: {"item": "T-Shirt", "price": 2500, "quantity": 10, "category": "Apparel", "expiry after months": 42},
           1108: {"item": "Clips", "price": 5, "quantity": 30, "category": "Household", "expiry after months": 0},
           1109: {"item": "Face wash", "price": 200, "quantity": 5, "category": "Toiletry", "expiry after months": 6},
           1110: {"item": "Shampoo", "price": 190, "quantity": 14, "category": "Toiletry", "expiry after months": 9},
           1111: {"item": "Maggi", "price": 25, "quantity": 20, "category": "Food", "expiry after months": 12},
           1112: {"item": "Chips", "price": 15, "quantity": 22, "category": "Food", "expiry after months": 12},
           1113: {"item": "Handwash", "price": 150, "quantity": 15, "category": "Toiletry", "expiry after months": 8},
           1114: {"item": "Eggs", "price": 10, "quantity": 30, "category": "Food", "expiry after months": 1},
           1115: {"item": "Trousers", "price": 870, "quantity": 8, "category": "Apparel", "expiry after months": 0},
           1116: {"item": "Batteries", "price": 14, "quantity": 23, "category": "Utilities", "expiry after months": 15},
           1117: {"item": "USB Cable", "price": 85, "quantity": 15, "category": "Electronics", "expiry after months": 24},
           1118: {"item": "Ball pens", "price": 12, "quantity": 8, "category": "Stationery", "expiry after months": 12},
           1119: {"item": "Biscuits", "price": 22, "quantity": 10, "category": "Food", "expiry after months": 6},
           1120: {"item": "Phone Charger", "price": 250, "quantity": 5, "category": "Utilities", "expiry after months": 48},
           1121: {"item": "Razor", "price": 150, "quantity": 6, "category": "Grooming", "expiry after months": 34},
           1122: {"item": "Earphones", "price": 290, "quantity": 15, "category": "Electronics", "expiry after months": 36},
           1123: {"item": "Pencils", "price": 5, "quantity": 30, "category": "Stationery", "expiry after months": 24},
           1124: {"item": "5 star", "price": 20, "quantity": 50, "category": "Food", "expiry after months": 15},
           1125: {"item": "Curd", "price": 32, "quantity": 12, "category": "Food", "expiry after months": 1},
           1126: {"item": "Dongle", "price": 750, "quantity": 5, "category": "Electronics", "expiry after months": 48},
           1127: {"item": "Butter", "price": 250, "quantity": 3, "category": "Stationery", "expiry after months": 36},
           1128: {"item": "Nutella", "price": 350, "quantity": 20, "category": "Food", "expiry after months": 10},
           1129: {"item": "Diary Milk", "price": 25, "quantity": 14, "category": "Food", "expiry after months": 12},
           1130: {"item": "Notebooks", "price": 150, "quantity": 17, "category": "Stationery", "expiry after months": 60},
           1131: {"item": "Oreo", "price": 35, "quantity": 9, "category": "Food", "expiry after months": 12}}

# %%
records
# Out:
# {1101: {'item': 'Toothpaste',
#   'price': 25,
#   'quantity': 30,
#   'category': 'Toiletry',
#   'expiry after months': 2},
#  1102: {'item': 'Carrots',
#   'price': 50,
#   'quantity': 24,
#   'category': 'Food',
#   'expiry after months': 1},
#  1103: {'item': 'Soap',
#   'price': 32,
#   'quantity': 15,
#   'category': 'Toiletry',
#   'expiry after months': 6},
#  1104: {'item': 'Tomatoes',
#   'price': 40,
#   'quantity': 12,
#   'category': 'Food',
#   'expiry after months': 1},
#  1105: {'item': 'Bananas',
#   'price': 20,
#   'quantity': 10,
#   'category': 'Food',
#   'expiry after months': 2},
#  1106: {'item': 'Socks',
#   'price': 56,
#   'quantity': 15,
#   'category': 'Apparel',
#   'expiry after months': 36},
#  1107: {'item': 'T-Shirt',
#   'price': 2500,
#   'quantity': 10,
#   'category': 'Apparel',
#   'expiry after months': 42},
#  1108: {'item': 'Clips',
#   'price': 5,
#   'quantity': 30,
#   'category': 'Household',
#   'expiry after months': 0},
# ...

# %%
reg = 1130
print(records[reg])
# Out:
# {'item': 'Notebooks', 'price': 150, 'quantity': 17, 'category': 'Stationery', 'expiry after months': 60}

# %%
import json

# %%
js_file = json.dumps(records) #converted dictionary to strings

# %%
js_file
# Out:
# '{"1101": {"item": "Toothpaste", "price": 25, "quantity": 30, "category": "Toiletry", "expiry after months": 2}, "1102": {"item": "Carrots", "price": 50, "quantity": 24, "category": "Food", "expiry after months": 1}, "1103": {"item": "Soap", "price": 32, "quantity": 15, "category": "Toiletry", "expiry after months": 6}, "1104": {"item": "Tomatoes", "price": 40, "quantity": 12, "category": "Food", "expiry after months": 1}, "1105": {"item": "Bananas", "price": 20, "quantity": 10, "category": "Food", "expiry after months": 2}, "1106": {"item": "Socks", "price": 56, "quantity": 15, "category": "Apparel", "expiry after months": 36}, "1107": {"item": "T-Shirt", "price": 2500, "quantity": 10, "category": "Apparel", "expiry after months": 42}, "1108": {"item": "Clips", "price": 5, "quantity": 30, "category": "Household", "expiry after months": 0}, "1109": {"item": "Face wash", "price": 200, "quantity": 5, "category": "Toiletry", "expiry after months": 6}, "1110": {"item": "Shampoo", "price"
# ...

# %% [markdown]
# ## Writing data in json file

# %%
fd = open("records.json",'w')

fd.write(js_file)

fd.close()

# %% [markdown]
# ## Reading data from json file

# %%
fd = open("records.json",'r')

re = fd.read()

fd.close()

# %%
re
# Out:
# '{"1101": {"item": "Toothpaste", "price": 25, "quantity": 30, "category": "Toiletry", "expiry after months": 2}, "1102": {"item": "Carrots", "price": 50, "quantity": 24, "category": "Food", "expiry after months": 1}, "1103": {"item": "Soap", "price": 32, "quantity": 15, "category": "Toiletry", "expiry after months": 6}, "1104": {"item": "Tomatoes", "price": 40, "quantity": 12, "category": "Food", "expiry after months": 1}, "1105": {"item": "Bananas", "price": 20, "quantity": 10, "category": "Food", "expiry after months": 2}, "1106": {"item": "Socks", "price": 56, "quantity": 15, "category": "Apparel", "expiry after months": 36}, "1107": {"item": "T-Shirt", "price": 2500, "quantity": 10, "category": "Apparel", "expiry after months": 42}, "1108": {"item": "Clips", "price": 5, "quantity": 30, "category": "Household", "expiry after months": 0}, "1109": {"item": "Face wash", "price": 200, "quantity": 5, "category": "Toiletry", "expiry after months": 6}, "1110": {"item": "Shampoo", "price"
# ...

# %%
records = json.loads(re) #converting back strings to dictionary

# %%
records
# Out:
# {'1101': {'item': 'Toothpaste',
#   'price': 25,
#   'quantity': 30,
#   'category': 'Toiletry',
#   'expiry after months': 2},
#  '1102': {'item': 'Carrots',
#   'price': 50,
#   'quantity': 24,
#   'category': 'Food',
#   'expiry after months': 1},
#  '1103': {'item': 'Soap',
#   'price': 32,
#   'quantity': 15,
#   'category': 'Toiletry',
#   'expiry after months': 6},
#  '1104': {'item': 'Tomatoes',
#   'price': 40,
#   'quantity': 12,
#   'category': 'Food',
#   'expiry after months': 1},
#  '1105': {'item': 'Bananas',
#   'price': 20,
#   'quantity': 10,
#   'category': 'Food',
#   'expiry after months': 2},
#  '1106': {'item': 'Socks',
#   'price': 56,
#   'quantity': 15,
#   'category': 'Apparel',
#   'expiry after months': 36},
#  '1107': {'item': 'T-Shirt',
#   'price': 2500,
#   'quantity': 10,
#   'category': 'Apparel',
#   'expiry after months': 42},
#  '1108': {'item': 'Clips',
#   'price': 5,
#   'quantity': 30,
#   'category': 'Household',
# ...

# %% [markdown]
# ## Adding New Item into Inventory

# %%
product_id = str(input("Enter the product id:"))
item = str(input("Enter name of the item:"))
price = int(input("Enter the price:"))
quantity = int(input("Enter the quantity:"))
category = str(input("Enter the item category"))
expiry = int(input("Enter the expiry in months:"))

records[product_id] = {'item': item, 'price': price, 'quantity': quantity, 'category': category, 'expiry in months': expiry}

js_file = json.dumps(records)

fd = open("records.json",'w')
fd.write(js_file)
fd.close()
# Out:
# Enter the product id:1132
# Enter name of the item:'Refills'
# Enter the price:4
# Enter the quantity:32
# Enter the item category'Stationery'
# Enter the expiry in months:18

# %%
records
# Out:
# {'1101': {'item': 'Toothpaste',
#   'price': 25,
#   'quantity': 30,
#   'category': 'Toiletry',
#   'expiry after months': 2},
#  '1102': {'item': 'Carrots',
#   'price': 50,
#   'quantity': 24,
#   'category': 'Food',
#   'expiry after months': 1},
#  '1103': {'item': 'Soap',
#   'price': 32,
#   'quantity': 15,
#   'category': 'Toiletry',
#   'expiry after months': 6},
#  '1104': {'item': 'Tomatoes',
#   'price': 40,
#   'quantity': 12,
#   'category': 'Food',
#   'expiry after months': 1},
#  '1105': {'item': 'Bananas',
#   'price': 20,
#   'quantity': 10,
#   'category': 'Food',
#   'expiry after months': 2},
#  '1106': {'item': 'Socks',
#   'price': 56,
#   'quantity': 15,
#   'category': 'Apparel',
#   'expiry after months': 36},
#  '1107': {'item': 'T-Shirt',
#   'price': 2500,
#   'quantity': 10,
#   'category': 'Apparel',
#   'expiry after months': 42},
#  '1108': {'item': 'Clips',
#   'price': 5,
#   'quantity': 30,
#   'category': 'Household',
# ...

# %%
del records['1130'] #Deleting items from the inventory

# %%
records
# Out:
# {'1101': {'item': 'Toothpaste',
#   'price': 25,
#   'quantity': 30,
#   'category': 'Toiletry',
#   'expiry after months': 2},
#  '1102': {'item': 'Carrots',
#   'price': 50,
#   'quantity': 24,
#   'category': 'Food',
#   'expiry after months': 1},
#  '1103': {'item': 'Soap',
#   'price': 32,
#   'quantity': 15,
#   'category': 'Toiletry',
#   'expiry after months': 6},
#  '1104': {'item': 'Tomatoes',
#   'price': 40,
#   'quantity': 12,
#   'category': 'Food',
#   'expiry after months': 1},
#  '1105': {'item': 'Bananas',
#   'price': 20,
#   'quantity': 10,
#   'category': 'Food',
#   'expiry after months': 2},
#  '1106': {'item': 'Socks',
#   'price': 56,
#   'quantity': 15,
#   'category': 'Apparel',
#   'expiry after months': 36},
#  '1107': {'item': 'T-Shirt',
#   'price': 2500,
#   'quantity': 10,
#   'category': 'Apparel',
#   'expiry after months': 42},
#  '1108': {'item': 'Clips',
#   'price': 5,
#   'quantity': 30,
#   'category': 'Household',
# ...

# %% [markdown]
# ## Buying the products

# %%
product_id = str(input("Enter the product id:"))
quantity = int(input("Enter the quantity:"))

records[product_id]['quantity'] = records[product_id]['quantity'] - quantity

print("item:", records[product_id]['item'])
print("price: ", records[product_id]['price'])
print("Bill Amount: ", records[product_id]['price'] * quantity)
# Out:
# Enter the product id:1131
# Enter the quantity:10
# item: Oreo
# price:  35
# Bill Amount:  350

# %% [markdown]
# ## Updating the inventory after buying

# %%
js_file = json.dumps(records)

fd = open("records.json",'w')
fd.write(js_file)
fd.close()

# %%
records
# Out:
# {'1101': {'item': 'Toothpaste',
#   'price': 25,
#   'quantity': 30,
#   'category': 'Toiletry',
#   'expiry after months': 2},
#  '1102': {'item': 'Carrots',
#   'price': 50,
#   'quantity': 24,
#   'category': 'Food',
#   'expiry after months': 1},
#  '1103': {'item': 'Soap',
#   'price': 32,
#   'quantity': 15,
#   'category': 'Toiletry',
#   'expiry after months': 6},
#  '1104': {'item': 'Tomatoes',
#   'price': 40,
#   'quantity': 12,
#   'category': 'Food',
#   'expiry after months': 1},
#  '1105': {'item': 'Bananas',
#   'price': 20,
#   'quantity': 10,
#   'category': 'Food',
#   'expiry after months': 2},
#  '1106': {'item': 'Socks',
#   'price': 56,
#   'quantity': 15,
#   'category': 'Apparel',
#   'expiry after months': 36},
#  '1107': {'item': 'T-Shirt',
#   'price': 2500,
#   'quantity': 10,
#   'category': 'Apparel',
#   'expiry after months': 42},
#  '1108': {'item': 'Clips',
#   'price': 5,
#   'quantity': 30,
#   'category': 'Household',
# ...

# %% [markdown]
# ## Sales (JSON)

# %%
{'product' : product_id, 'quantity' : quantity, 'amount': records[product_id]['price'] * quantity}
# Out:
# {'product': '1131', 'quantity': 10, 'amount': 350}

# %%
sales = {  1120: {"item": "Phone Charger", "price": 250, "quantity": 5, "category": "Utilities", "expiry after months": 48},
           1121: {"item": "Razor", "price": 150, "quantity": 6, "category": "Grooming", "expiry after months": 34},
           1122: {"item": "Earphones", "price": 290, "quantity": 15, "category": "Electronics", "expiry after months": 36},
           1123: {"item": "Pencils", "price": 5, "quantity": 30, "category": "Stationery", "expiry after months": 24}}

# %%
json.dumps(sales)
# Out:
# '{"1120": {"item": "Phone Charger", "price": 250, "quantity": 5, "category": "Utilities", "expiry after months": 48}, "1121": {"item": "Razor", "price": 150, "quantity": 6, "category": "Grooming", "expiry after months": 34}, "1122": {"item": "Earphones", "price": 290, "quantity": 15, "category": "Electronics", "expiry after months": 36}, "1123": {"item": "Pencils", "price": 5, "quantity": 30, "category": "Stationery", "expiry after months": 24}}'

# %%
# Adding to json file of Sales
fd = open("sales.json",'w')
fd.write(json.dumps(sales))
fd.close()
